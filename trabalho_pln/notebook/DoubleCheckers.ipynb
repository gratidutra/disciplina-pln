# %%
import pandas as pd
import json
from collections import defaultdict

# %%
# Lista dos arquivos de cada anotador
arquivos = ['../data/checkers/cesar.jsonl', '../data/checkers/marilia.jsonl', 
            '../data/checkers/murilo.jsonl', '../data/checkers/natassia.jsonl']
dados = []

# Função para extrair apenas os nomes das labels
def extrair_labels(label_list):
    return [l[2] for l in label_list] if isinstance(label_list, list) else []

# Lê cada .jsonl e guarda os dados
for i, caminho in enumerate(arquivos, 1):
    anotador = f"Anotador_{i}"
    with open(caminho, 'r', encoding='utf-8') as f:
        for linha in f:
            obj = json.loads(linha)
            texto = obj['text'].strip()
            labels = extrair_labels(obj.get('label', []))
            dados.append({'text': texto, 'anotador': anotador, 'labels': labels})

# Converte para DataFrame
df = pd.DataFrame(dados)

df
# Out:
#                                                  text    anotador  \
# 0   ## Reversible folding energetics of Yersinia A...  Anotador_1
# 1   ## Controlling Structure and Dimensions of a D...  Anotador_1
# 2   ## Deletion of heat shock protein 60 in adult ...  Anotador_1
# 3   ## Europe PMC Funders Group\n\nAuthor Manuscri...  Anotador_1
# 4   ## A small molecule chaperone rescues the stab...  Anotador_1
# 5   ## USP33 deubiquitinates PRKN/parkin and antag...  Anotador_1
# 6   ## Intracerebroventricular enzyme replacement ...  Anotador_1
# 7   ## Concomitant targeting of BCL2 with venetocl...  Anotador_1
# 8   ## Reversible folding energetics of Yersinia A...  Anotador_2
# 9   ## Controlling Structure and Dimensions of a D...  Anotador_2
# 10  ## Deletion of heat shock protein 60 in adult ...  Anotador_2
# 11  ## Europe PMC Funders Group\n\nAuthor Manuscri...  Anotador_2
# 12  ## A small molecule chaperone rescues the stab...  Anotador_2
# 13  ## USP33 deubiquitinates PRKN/parkin and antag...  Anotador_2
# 14  ## Intracerebroventricular enzyme replacement ...  Anotador_2
# 15  ## Concomitant targeting of BCL2 with venetocl...  Anotador_2
# 16  ## Reversible folding energetics of Yersinia A...  Anotador_3
# 17  ## Controlling Structure and Dimensions of a D...  Anotador_3
# 18  ## Deletion of heat shock protein 60 in adult ...  Anotador_3
# 19  ## Europe PMC Funders Group\n\nAuthor Manuscri...  Anotador_3
# 20  ## A small molecule chaperone rescues the stab...  Anotador_3
# 21  ## USP33 deubiquitinates PRKN/parkin and antag...  Anotador_3
# 22  ## Intracerebroventricular enzyme replacement ...  Anotador_3
# 23  ## Concomitant targeting of BCL2 with venetocl...  Anotador_3
# 24  ## Reversible folding energetics of Yersinia A...  Anotador_4
# 25  ## Controlling Structure and Dimensions of a D...  Anotador_4
# 26  ## Deletion of heat shock protein 60 in adult ...  Anotador_4
# 27  ## Europe PMC Funders Group\n\nAuthor Manuscri...  Anotador_4
# 28  ## A small molecule chaperone rescues the stab...  Anotador_4
# 29  ## USP33 deubiquitinates PRKN/parkin and antag...  Anotador_4
# 30  ## Intracerebroventricular enzyme replacement ...  Anotador_4
# 31  ## Concomitant targeting of BCL2 with venetocl...  Anotador_4
#
#                                                labels
# 0   [Mutation, Method, Method, Method, Measure, Me...
# 1                [Measure, Measure, Measure, Measure]
# 2                                    [Method, Method]
# 3   [Mutation, Method, Method, Method, Measure, Me...
# 4   [Method, Method, Mutation, Mutation, Mutation,...
# 5                                                  []
# 6                                           [Measure]
# 7                [Gene, Gene, Gene, Gene, Gene, Gene]
# 8   [Mutation, Mutation, Mutation, Mutation, Gene,...
# 9   [Gene, Mutation, Mutation, Measure, Mutation, ...
# 10  [Mutation, Mutation, Mutation, Mutation, Mutat...
# 11  [Mutation, Gene, Measure, Gene, Gene, Measure,...
# 12  [Gene, Mutation, Mutation, Mutation, Gene, Gen...
# 13  [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
# 14  [Gene, Gene, Method, Method, Method, Method, M...
# 15  [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
# 16                               [Mutation, Mutation]
# 17                                                 []
# 18                       [Mutation, Gene, Gene, Gene]
# 19                                         [Mutation]
# 20                                   [Gene, Mutation]
# 21                                       [Gene, Gene]
# 22                                             [Gene]
# 23                           [Gene, Gene, Gene, Gene]
# 24                                                 []
# 25                                          [Measure]
# 26                                                 []
# 27                                          [Measure]
# 28  [Mutation, Mutation, Mutation, Mutation, Mutat...
# 29  [Gene, Gene, Gene, Gene, Gene, Mutation, Mutat...
# 30                     [Mutation, Mutation, Mutation]
# 31           [Mutation, Mutation, Mutation, Mutation]

# %%
# Pivotar: um texto por linha, uma coluna por anotador com as labels extraídas
df_pivot = df.pivot_table(index='text', columns='anotador', values='labels', aggfunc=lambda x: x)

# Corrigir valores NaN (não anotado) para lista vazia
df_pivot = df_pivot.applymap(lambda x: x if isinstance(x, list) else [])

# Visualizar
df_pivot =df_pivot.reset_index()

df_pivot
# Out:
# anotador                                               text  \
# 0         ## A small molecule chaperone rescues the stab...
# 1         ## Concomitant targeting of BCL2 with venetocl...
# 2         ## Controlling Structure and Dimensions of a D...
# 3         ## Deletion of heat shock protein 60 in adult ...
# 4         ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 5         ## Intracerebroventricular enzyme replacement ...
# 6         ## Reversible folding energetics of Yersinia A...
# 7         ## USP33 deubiquitinates PRKN/parkin and antag...
#
# anotador                                         Anotador_1  \
# 0         [Method, Method, Mutation, Mutation, Mutation,...
# 1                      [Gene, Gene, Gene, Gene, Gene, Gene]
# 2                      [Measure, Measure, Measure, Measure]
# 3                                          [Method, Method]
# 4         [Mutation, Method, Method, Method, Measure, Me...
# 5                                                 [Measure]
# 6         [Mutation, Method, Method, Method, Measure, Me...
# 7                                                        []
#
# anotador                                         Anotador_2  \
# 0         [Gene, Mutation, Mutation, Mutation, Gene, Gen...
# 1         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
# 2         [Gene, Mutation, Mutation, Measure, Mutation, ...
# 3         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 4         [Mutation, Gene, Measure, Gene, Gene, Measure,...
# 5         [Gene, Gene, Method, Method, Method, Method, M...
# 6         [Mutation, Mutation, Mutation, Mutation, Gene,...
# 7         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
#
# anotador                    Anotador_3  \
# 0                     [Gene, Mutation]
# 1             [Gene, Gene, Gene, Gene]
# 2                                   []
# 3         [Mutation, Gene, Gene, Gene]
# 4                           [Mutation]
# 5                               [Gene]
# 6                 [Mutation, Mutation]
# 7                         [Gene, Gene]
#
# anotador                                         Anotador_4
# 0         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 1                  [Mutation, Mutation, Mutation, Mutation]
# 2                                                 [Measure]
# 3                                                        []
# 4                                                 [Measure]
# 5                            [Mutation, Mutation, Mutation]
# 6                                                        []
# 7         [Gene, Gene, Gene, Gene, Gene, Mutation, Mutat...

# %%
pesos = {
    "Measure": 0.5,
    "Gene": 0.1666,
    "Method": 0.1666,
    "Mutation": 0.1666
}

# Limite da moda: label deve aparecer em pelo menos 2 anotadores
limite_moda = 2

# Função que calcula o score considerando a moda e os pesos definidos
def score_com_pesos(row):
    contador = Counter()
    for labels in row:
        if isinstance(labels, list):
            for label in labels:
                if label in pesos:
                    contador[label] += 1
    # Aplica a moda
    labels_validas = [label for label, count in contador.items() if count >= limite_moda]
    # Soma os pesos
    return sum(pesos[label] for label in labels_validas)

# Aplica por linha (por artigo)
df_pivot['score_moda_pesado'] = df_pivot.apply(score_com_pesos, axis=1)

# Visualizar resultado
print(df_pivot[['score_moda_pesado']].value_counts())
# Out:
# score_moda_pesado
# 0.4998               4
# 0.9998               3
# 0.8332               1
# Name: count, dtype: int64

# %%
df_pivot['model'] = [0, 0, 1, 0, 1, 1, 1, 1 ]
#df_pivot['Real'] = [0, 0, 1, 0, 1, 0, 1, 0 ]

# %%
# Se score == 1.0, então binário = 1; senão 0
df_pivot['estimado_binario'] = df_pivot['score_moda_pesado'].apply(lambda x: 1 if x > 0.5 else 0)

from sklearn.metrics import cohen_kappa_score

# Calcular kappa
kappa = cohen_kappa_score(df_pivot['model'], df_pivot['estimado_binario'])

print(f"Cohen's Kappa: {kappa:.4f}")
# Out:
# Cohen's Kappa: 0.7500

# %%
df_pivot
# Out:
# anotador                                               text  \
# 0         ## A small molecule chaperone rescues the stab...
# 1         ## Concomitant targeting of BCL2 with venetocl...
# 2         ## Controlling Structure and Dimensions of a D...
# 3         ## Deletion of heat shock protein 60 in adult ...
# 4         ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 5         ## Intracerebroventricular enzyme replacement ...
# 6         ## Reversible folding energetics of Yersinia A...
# 7         ## USP33 deubiquitinates PRKN/parkin and antag...
#
# anotador                                         Anotador_1  \
# 0         [Method, Method, Mutation, Mutation, Mutation,...
# 1                      [Gene, Gene, Gene, Gene, Gene, Gene]
# 2                      [Measure, Measure, Measure, Measure]
# 3                                          [Method, Method]
# 4         [Mutation, Method, Method, Method, Measure, Me...
# 5                                                 [Measure]
# 6         [Mutation, Method, Method, Method, Measure, Me...
# 7                                                        []
#
# anotador                                         Anotador_2  \
# 0         [Gene, Mutation, Mutation, Mutation, Gene, Gen...
# 1         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
# 2         [Gene, Mutation, Mutation, Measure, Mutation, ...
# 3         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 4         [Mutation, Gene, Measure, Gene, Gene, Measure,...
# 5         [Gene, Gene, Method, Method, Method, Method, M...
# 6         [Mutation, Mutation, Mutation, Mutation, Gene,...
# 7         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
#
# anotador                    Anotador_3  \
# 0                     [Gene, Mutation]
# 1             [Gene, Gene, Gene, Gene]
# 2                                   []
# 3         [Mutation, Gene, Gene, Gene]
# 4                           [Mutation]
# 5                               [Gene]
# 6                 [Mutation, Mutation]
# 7                         [Gene, Gene]
#
# anotador                                         Anotador_4  \
# 0         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 1                  [Mutation, Mutation, Mutation, Mutation]
# 2                                                 [Measure]
# 3                                                        []
# 4                                                 [Measure]
# 5                            [Mutation, Mutation, Mutation]
# 6                                                        []
# 7         [Gene, Gene, Gene, Gene, Gene, Mutation, Mutat...
#
# anotador  score_moda_pesado  model  estimado_binario
# 0                    0.4998      0                 0
# 1                    0.4998      0                 0
# 2                    0.9998      1                 1
# 3                    0.4998      0                 0
# 4                    0.9998      1                 1
# 5                    0.9998      1                 1
# 6                    0.8332      1                 1
# 7                    0.4998      1                 0
