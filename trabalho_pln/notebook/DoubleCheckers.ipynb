# %%
import pandas as pd
import json
from collections import defaultdict
import os
from collections import Counter

# %%
arquivos = [
    '../data/checkers/cesar.jsonl',
    '../data/checkers/marilia.jsonl',
    '../data/checkers/murilo.jsonl',
    '../data/checkers/natassia.jsonl'
]

dados = []

for caminho in arquivos:
    anotador = os.path.basename(caminho).replace('.jsonl', '')  # Ex: "cesar"
    
    with open(caminho, 'r', encoding='utf-8') as f:
        for linha in f:
            entrada = json.loads(linha)
            texto = entrada.get('text', '')
            labels = entrada.get('label', [])
            
            row = {"annotator": anotador, "text": texto}
            
            for start, end, label in labels:
                entidade = texto[start:end].strip()
                if entidade:
                    if label not in row:
                        row[label] = [entidade]
                    else:
                        row[label].append(entidade)

            # Convertendo listas para strings separadas por vírgula
            for chave in row:
                if isinstance(row[chave], list):
                    row[chave] = ', '.join(sorted(set(row[chave])))
            
            dados.append(row)

# Criar DataFrame
df = pd.DataFrame(dados)

# Visualizar
#df.to_csv('../data/double_checkers.csv')
df
# Out:
#    annotator                                               text  \
# 0      cesar  ## Reversible folding energetics of Yersinia A...
# 1      cesar  ## Controlling Structure and Dimensions of a D...
# 2      cesar  ## Deletion of heat shock protein 60 in adult ...
# 3      cesar  ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 4      cesar  ## A small molecule chaperone rescues the stab...
# 5      cesar  ## USP33 deubiquitinates PRKN/parkin and antag...
# 6      cesar  ## Intracerebroventricular enzyme replacement ...
# 7      cesar  ## Concomitant targeting of BCL2 with venetocl...
# 8    marilia  ## Reversible folding energetics of Yersinia A...
# 9    marilia  ## Controlling Structure and Dimensions of a D...
# 10   marilia  ## Deletion of heat shock protein 60 in adult ...
# 11   marilia  ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 12   marilia  ## A small molecule chaperone rescues the stab...
# 13   marilia  ## USP33 deubiquitinates PRKN/parkin and antag...
# 14   marilia  ## Intracerebroventricular enzyme replacement ...
# 15   marilia  ## Concomitant targeting of BCL2 with venetocl...
# 16    murilo  ## Reversible folding energetics of Yersinia A...
# 17    murilo  ## Controlling Structure and Dimensions of a D...
# 18    murilo  ## Deletion of heat shock protein 60 in adult ...
# 19    murilo  ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 20    murilo  ## A small molecule chaperone rescues the stab...
# 21    murilo  ## USP33 deubiquitinates PRKN/parkin and antag...
# 22    murilo  ## Intracerebroventricular enzyme replacement ...
# 23    murilo  ## Concomitant targeting of BCL2 with venetocl...
# 24  natassia  ## Reversible folding energetics of Yersinia A...
# 25  natassia  ## Controlling Structure and Dimensions of a D...
# 26  natassia  ## Deletion of heat shock protein 60 in adult ...
# 27  natassia  ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 28  natassia  ## A small molecule chaperone rescues the stab...
# 29  natassia  ## USP33 deubiquitinates PRKN/parkin and antag...
# 30  natassia  ## Intracerebroventricular enzyme replacement ...
# 31  natassia  ## Concomitant targeting of BCL2 with venetocl...
#
#                                              Mutation  \
# 0                                          W 42, W42X
# 1                                                 NaN
# 2                                                 NaN
# 3                                          W 42, W42X
# 4                                               P187S
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                          W 149, W 149 → Y/F/A, W 42
# 9   A29V, A29V/A48M, D34S, K35, K35Q, P33A, P33G, ...
# 10  Deletion of HSP60, HSP60, HSP60 (HSP60-depende...
# 11                         W 149 → Y/F/A, W149F, W42F
# 12                   C609T, NQO1 P187S, NQO1*2, P187S
# 13                          K11, K48, K6, K63, Lys435
# 14                                                NaN
# 15                   BRAF-  and  KRASmutant, mTORC1/2
# 16                                        W149X, W42X
# 17                                                NaN
# 18                                     HSP60 CKO mice
# 19                                               W42X
# 20                                              P187S
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                              P187S
# 29                         E3 ubiquitin ligase, PINK1
# 30                          -gal de, es of G, sidosis
# 31                                                AML
#
#                                                Method  \
# 0               GdnHCl, guanidine hydrochloride, urea
# 1                                                 NaN
# 2                                          Urea, urea
# 3               GdnHCl, guanidine hydrochloride, urea
# 4                   HDX-MS, Thermal shift assay, urea
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   GdnHCl, GdnHCl (guanidine hydrochloride), SYPR...
# 9                 SEC, analytical ultracentrifugation
# 10            SP60 CKO, heat shock protein 60 (HSP60)
# 11  CD, HSQC-TROSY, J-815 CD spectropolarimeter (J...
# 12  HDX-MS, HSQC, ITC, SAXS, heteronuclear single ...
# 13  1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine, ...
# 14  )ap, broventricularly (ICV) ad, chr, effectiv,...
# 15  CountBright  counting  beads, RNA  sequencing,...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                             HDX-MS
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                               Measure  \
# 0                              CD, circular dichroism
# 1                              CD, circular dichroism
# 2                                                 NaN
# 3                              CD, circular dichroism
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  gl
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  CD
# 10                                                NaN
# 11  C, DPR, MHz, kcal mol -1, mM, molar ellipticit...
# 12                                                NaN
# 13                                                NaN
# 14                                                ted
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                 CD
# 26                                                NaN
# 27                                                 CD
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                                  Gene
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                NQO1
# 5                                                 NaN
# 6                                                 NaN
# 7                        EGFR, KRAS, KRASmutant, TP53
# 8                                                 Ail
# 9                                                CytR
# 10                                HSP10, HSP60, HSP70
# 11  Ail, FomA, OmpA, OmpLA, OmpX, PagP, VDAC, W 14...
# 12                          NQO1, p33 ING1b, p53, p73
# 13               PINK1, PINK1-PRKN, PRKN, USP33, VDU1
# 14                           B1 ), alactosidase 𝛃 1 (
# 15  BCL2, BIM, GDC-0973, IDH1, IDH2, MAPK, MCL1, M...
# 16                                                NaN
# 17                                                NaN
# 18                                   BAX, BCL2, HSP60
# 19                                                NaN
# 20                                               NQO1
# 21                                        PRKN, USP33
# 22                                           ain (MB,
# 23                               BCL2, BIM, MCL1, MYC
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                               NQO1
# 29                                              USP33
# 30                                                NaN
# 31                                                NaN

# %%
pesos = {
    "Measure": 0.5,
    "Gene": 0.1666,
    "Method": 0.1666,
    "Mutation": 0.1666
}

# Limite da moda: label deve aparecer em pelo menos 2 anotadores
limite_moda = 3

# Função que calcula o score considerando a moda e os pesos definidos
def score_com_pesos(row):
    contador = Counter()
    for labels in row:
        if isinstance(labels, list):
            for label in labels:
                if label in pesos:
                    contador[label] += 1
    # Aplica a moda
    labels_validas = [label for label, count in contador.items() if count >= limite_moda]
    # Soma os pesos
    return sum(pesos[label] for label in labels_validas)

# Aplica por linha (por artigo)
df_pivot['score_moda_pesado'] = df_pivot.apply(score_com_pesos, axis=1)

df_pivot['pmid'] = ['31605637', '31123034', '31557007', '31209364','31672545' ,'31481471','31672545','31432739']

# Visualizar resultado
df_pivot[['score_moda_pesado']].value_counts()
# Out:
# score_moda_pesado
# 0.4998               5
# 0.6666               1
# 0.8332               1
# 0.9998               1
# Name: count, dtype: int64

# %%
df_pivot
# Out:
# anotador                                               text  \
# 0         ## A small molecule chaperone rescues the stab...
# 1         ## Concomitant targeting of BCL2 with venetocl...
# 2         ## Controlling Structure and Dimensions of a D...
# 3         ## Deletion of heat shock protein 60 in adult ...
# 4         ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 5         ## Intracerebroventricular enzyme replacement ...
# 6         ## Reversible folding energetics of Yersinia A...
# 7         ## USP33 deubiquitinates PRKN/parkin and antag...
#
# anotador                                         Anotador_1  \
# 0         [Method, Method, Mutation, Mutation, Mutation,...
# 1                      [Gene, Gene, Gene, Gene, Gene, Gene]
# 2                      [Measure, Measure, Measure, Measure]
# 3                                          [Method, Method]
# 4         [Mutation, Method, Method, Method, Measure, Me...
# 5                                                 [Measure]
# 6         [Mutation, Method, Method, Method, Measure, Me...
# 7                                                        []
#
# anotador                                         Anotador_2  \
# 0         [Gene, Mutation, Mutation, Mutation, Gene, Gen...
# 1         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
# 2         [Gene, Mutation, Mutation, Measure, Mutation, ...
# 3         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 4         [Mutation, Gene, Measure, Gene, Gene, Measure,...
# 5         [Gene, Gene, Method, Method, Method, Method, M...
# 6         [Mutation, Mutation, Mutation, Mutation, Gene,...
# 7         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
#
# anotador                    Anotador_3  \
# 0                     [Gene, Mutation]
# 1             [Gene, Gene, Gene, Gene]
# 2                                   []
# 3         [Mutation, Gene, Gene, Gene]
# 4                           [Mutation]
# 5                               [Gene]
# 6                 [Mutation, Mutation]
# 7                         [Gene, Gene]
#
# anotador                                         Anotador_4  \
# 0         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 1                  [Mutation, Mutation, Mutation, Mutation]
# 2                                                 [Measure]
# 3                                                        []
# 4                                                 [Measure]
# 5                            [Mutation, Mutation, Mutation]
# 6                                                        []
# 7         [Gene, Gene, Gene, Gene, Gene, Mutation, Mutat...
#
# anotador  score_moda_pesado      pmid  model  estimado_binario
# 0                    0.4998  31605637      0                 0
# 1                    0.4998  31123034      0                 0
# 2                    0.6666  31557007      1                 1
# 3                    0.4998  31209364      0                 0
# 4                    0.9998  31672545      1                 1
# 5                    0.4998  31481471      1                 1
# 6                    0.8332  31672545      1                 1
# 7                    0.4998  31432739      0                 0

# %%
#df_pivot['model'] =[0.49, 0.33, 0.67, 0.498, 0.83, 0.83, 0.83, 0.33]
df_pivot['model'] = [0,    0,    1,    0,     1,    1,    1,    0]
#df_pivot['Real'] = [0,    0,    1,    0,     1,    0,    1,    0 ]

# %%
# Se score == 1.0, então binário = 1; senão 0
df_pivot['estimado_binario'] = df_pivot['score_moda_pesado'].apply(lambda x: 1 if x > 0.5 else 0)

from sklearn.metrics import cohen_kappa_score

# Calcular kappa
kappa = cohen_kappa_score(df_pivot['model'], df_pivot['estimado_binario'])

print(f"Cohen's Kappa: {kappa:.4f}")
# Out:
# Cohen's Kappa: 0.7500

# %%
df_pivot
# Out:
# anotador                                               text  \
# 0         ## A small molecule chaperone rescues the stab...
# 1         ## Concomitant targeting of BCL2 with venetocl...
# 2         ## Controlling Structure and Dimensions of a D...
# 3         ## Deletion of heat shock protein 60 in adult ...
# 4         ## Europe PMC Funders Group\n\nAuthor Manuscri...
# 5         ## Intracerebroventricular enzyme replacement ...
# 6         ## Reversible folding energetics of Yersinia A...
# 7         ## USP33 deubiquitinates PRKN/parkin and antag...
#
# anotador                                         Anotador_1  \
# 0         [Method, Method, Mutation, Mutation, Mutation,...
# 1                      [Gene, Gene, Gene, Gene, Gene, Gene]
# 2                      [Measure, Measure, Measure, Measure]
# 3                                          [Method, Method]
# 4         [Mutation, Method, Method, Method, Measure, Me...
# 5                                                 [Measure]
# 6         [Mutation, Method, Method, Method, Measure, Me...
# 7                                                        []
#
# anotador                                         Anotador_2  \
# 0         [Gene, Mutation, Mutation, Mutation, Gene, Gen...
# 1         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
# 2         [Gene, Mutation, Mutation, Measure, Mutation, ...
# 3         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 4         [Mutation, Gene, Measure, Gene, Gene, Measure,...
# 5         [Gene, Gene, Method, Method, Method, Method, M...
# 6         [Mutation, Mutation, Mutation, Mutation, Gene,...
# 7         [Gene, Gene, Gene, Gene, Gene, Gene, Gene, Gen...
#
# anotador                    Anotador_3  \
# 0                     [Gene, Mutation]
# 1             [Gene, Gene, Gene, Gene]
# 2                                   []
# 3         [Mutation, Gene, Gene, Gene]
# 4                           [Mutation]
# 5                               [Gene]
# 6                 [Mutation, Mutation]
# 7                         [Gene, Gene]
#
# anotador                                         Anotador_4  \
# 0         [Mutation, Mutation, Mutation, Mutation, Mutat...
# 1                  [Mutation, Mutation, Mutation, Mutation]
# 2                                                 [Measure]
# 3                                                        []
# 4                                                 [Measure]
# 5                            [Mutation, Mutation, Mutation]
# 6                                                        []
# 7         [Gene, Gene, Gene, Gene, Gene, Mutation, Mutat...
#
# anotador  score_moda_pesado      pmid  model  estimado_binario
# 0                    0.4998  31605637      0                 0
# 1                    0.4998  31123034      0                 0
# 2                    0.6666  31557007      1                 1
# 3                    0.4998  31209364      0                 0
# 4                    0.9998  31672545      1                 1
# 5                    0.4998  31481471      1                 0
# 6                    0.8332  31672545      1                 1
# 7                    0.4998  31432739      0                 0
